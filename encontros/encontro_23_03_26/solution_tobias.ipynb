# %%
sequence = "..."

sequenceLength = len(sequence)
cCount = sequence.count('C')
gCount = sequence.count('G')

print("Tamanho da sequência: ", sequenceLength)
print("Número de C: ", cCount)
print("Número de G: ", gCount)
print("Porcentagem de C e G: ", round((cCount + gCount) / sequenceLength * 100, 2), "%")
# Out:
# Tamanho da sequência:  680
# Número de C:  163
# Número de G:  167
# Porcentagem de C e G:  48.53 %
