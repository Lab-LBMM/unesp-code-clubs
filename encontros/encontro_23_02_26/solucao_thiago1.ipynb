# %% [markdown]
# # Lista de espécies

# %%
nome = ["Renato", "Thiago","Pepijn"]

# %%
print(nome)
# Out:
# ['Renato', 'Thiago', 'Pepijn']

# %%
levantamento = [
    "Melipona scutellaris",
    "Scaptotrigona postica",
    "Tetragonisca angustula",
    "Melipona scutellaris",
    "Scaptotrigona postica",
    "Scaptotrigona depilis",
    "Melipona quadrifasciata",
    "Friesiomelita varia",
    "Scaptotrigona postica"
]

# %% [markdown]
# # 1) Enumere os ninhos observados na ordem em que aparecem na lista.

# %%
for nome in levantamento:
    print("Ninho", ":", nome)
# Out:
# Ninho : Melipona scutellaris
# Ninho : Scaptotrigona postica
# Ninho : Tetragonisca angustula
# Ninho : Melipona scutellaris
# Ninho : Scaptotrigona postica
# Ninho : Scaptotrigona depilis
# Ninho : Melipona quadrifasciata
# Ninho : Friesiomelita varia
# Ninho : Scaptotrigona postica

# %%
for i, especie in enumerate(levantamento, start=1):
    print("Ninho", i, ":", especie)
# Out:
# Ninho 1 : Melipona scutellaris
# Ninho 2 : Scaptotrigona postica
# Ninho 3 : Tetragonisca angustula
# Ninho 4 : Melipona scutellaris
# Ninho 5 : Scaptotrigona postica
# Ninho 6 : Scaptotrigona depilis
# Ninho 7 : Melipona quadrifasciata
# Ninho 8 : Friesiomelita varia
# Ninho 9 : Scaptotrigona postica

# %%
help(enumerate)
# Out:
# Help on class enumerate in module builtins:
#
# class enumerate(object)
#  |  enumerate(iterable, start=0)
#  |
#  |  Return an enumerate object.
#  |
#  |    iterable
#  |      an object supporting iteration
#  |
#  |  The enumerate object yields pairs containing a count (from start, which
#  |  defaults to zero) and a value yielded by the iterable argument.
#  |
#  |  enumerate is useful for obtaining an indexed list:
#  |      (0, seq[0]), (1, seq[1]), (2, seq[2]), ...
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(self, /)
#  |      Return state information for pickling.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  __class_getitem__(object, /)
#  |      See PEP 585
#  |
# ...

# %% [markdown]
# # 2) Mostre o total de ninhos observados.

# %%
print(len(levantamento))
# Out:
# 9

# %%
print("Total de ninhos observados: \n\n", len(levantamento))
# Out:
# Total de ninhos observados:
#
#  9

# %%
print(f"Total de ninhos observados: \n\n{len(levantamento)}")
# Out:
# Total de ninhos observados:
#
# 9

# %% [markdown]
# # 3) Calcule quantos ninhos existem de cada espécie.

# %%
contagem_especies = {}

# %%
{"especie 1": 4, "especie 2": 6}
# Out:
# {'especie 1': 4, 'especie 2': 6}

# %%
contagem_especies
# Out:
# {'Melipona scutellaris': 14,
#  'Scaptotrigona postica': 21,
#  'Tetragonisca angustula': 7,
#  'Scaptotrigona depilis': 7,
#  'Melipona quadrifasciata': 7,
#  'Friesiomelita varia': 7}

# %%
contagem_especies.get("Melipona sp", 0)
# Out:
# 0

# %%
contagem_especies = {}
for nome in levantamento:
    contagem_especies[nome] = contagem_especies.get(nome, 0) + 1

# %%
print(contagem_especies)
# Out:
# {'Melipona scutellaris': 2, 'Scaptotrigona postica': 3, 'Tetragonisca angustula': 1, 'Scaptotrigona depilis': 1, 'Melipona quadrifasciata': 1, 'Friesiomelita varia': 1}

# %%
help("for")
# Out:
# The "for" statement
# *******************
#
# The "for" statement is used to iterate over the elements of a sequence
# (such as a string, tuple or list) or other iterable object:
#
#    for_stmt ::= "for" target_list "in" starred_list ":" suite
#                 ["else" ":" suite]
#
# The "starred_list" expression is evaluated once; it should yield an
# *iterable* object.  An *iterator* is created for that iterable. The
# first item provided by the iterator is then assigned to the target
# list using the standard rules for assignments (see Assignment
# statements), and the suite is executed.  This repeats for each item
# provided by the iterator.  When the iterator is exhausted, the suite
# in the "else" clause, if present, is executed, and the loop
# terminates.
#
# A "break" statement executed in the first suite terminates the loop
# without executing the "else" clause’s suite.  A "continue" statement
# executed in the first suite skips the rest of the suite and continues
# ...

# %% [markdown]
# # 4) Calcule quantos ninhos existem de cada gênero.

# %%
contagem_genero = {}

# %%
for nome in levantamento:
    genero = nome.split()[0]
    contagem_genero[genero] = contagem_genero.get(genero, 0) +1

# %%
print(contagem_genero)
# Out:
# {'Melipona': 3, 'Scaptotrigona': 4, 'Tetragonisca': 1, 'Friesiomelita': 1}

# %%
nome.split()
# Out:
# ['Scaptotrigona', 'postica']

# %%
contagem_genero
# Out:
# {'Melipona': 3, 'Scaptotrigona': 4, 'Tetragonisca': 1, 'Friesiomelita': 1}

# %%
contagem_genero
contagem_genero
# Out:
# {'Melipona': 3, 'Scaptotrigona': 4, 'Tetragonisca': 1, 'Friesiomelita': 1}

# %%
print(contagem_genero)
print(contagem_genero)
# Out:
# {'Melipona': 3, 'Scaptotrigona': 4, 'Tetragonisca': 1, 'Friesiomelita': 1}
# {'Melipona': 3, 'Scaptotrigona': 4, 'Tetragonisca': 1, 'Friesiomelita': 1}
